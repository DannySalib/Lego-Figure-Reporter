# %%
from open3d import io, visualization

output = io.read_point_cloud("scans/test2/dense/result.ply")  # Read point cloud
visualization.draw_geometries([output])  # Visualize point cloud
# Out:
# [Open3D WARNING] Read PLY failed: number of vertex <= 0.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
