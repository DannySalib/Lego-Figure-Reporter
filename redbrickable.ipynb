# %% [markdown]
# Dataset link
# https://cdn.rebrickable.com/media/downloads/minifigs.csv.zip?1765350724.8110726
#
# I used wget to install. This provides fig_num,name,num_parts, img_url

# %%
import pandas as pd

df = pd.read_csv('./minifigs.csv', index_col=0)
df.head()
# Out:
#                                                 name  num_parts  \
# fig_num
# fig-000001                        Toy Store Employee          4
# fig-000002                              Customer Kid          4
# fig-000003                     Assassin Droid, White          8
# fig-000004  Man, White Torso, Black Legs, Brown Hair          4
# fig-000005           Captain America with Short Legs          3
#
#                                                       img_url
# fig_num
# fig-000001  https://cdn.rebrickable.com/media/sets/fig-000...
# fig-000002  https://cdn.rebrickable.com/media/sets/fig-000...
# fig-000003  https://cdn.rebrickable.com/media/sets/fig-000...
# fig-000004  https://cdn.rebrickable.com/media/sets/fig-000...
# fig-000005  https://cdn.rebrickable.com/media/sets/fig-000...
